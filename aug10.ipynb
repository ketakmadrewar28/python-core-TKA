# %% [markdown]
# # Operators
# ## Relational / Comparison Operators
# ### > , < , >= , <=
# ## Equality Operators
# ### == (Equals to Equals) , != (Not Equals to)
#
# ## Relational operators always returns boolean vlaue (True / False)

# %%
jay = 21
viru = 22
print(jay > viru) # False
# Out:
# False

# %%
jay = 22
viru = 22
res1 = jay != viru 
res2 = jay == viru
print(res1 , res2)
# Out:
# False True

# %% [markdown]
# # Conditional Statements
#
# ## if :->
# ### To check half condition
#
# ## if - else
# ### ---> We use if - else to check one complete condition
# ### sty:->      if condition :
# ###                     if block code
# ###             else :
# ###                     else block code

# %%
jay = 23
viru = 23
# Who will pay the bill

if jay > viru:  # False
    print("Jay will pay the bill")

elif jay == viru:
    print("TTMM")

else:
    print("Viru will pay the bill")

print("End of program")
# Out:
# TTMM
# End of program

# %% [markdown]
# ## Logical Operators
# ### and
# ### or
# ### not
#
# ### for logical operations on data we use Logical operators

# %% [markdown]
# ## and operator :->
#         If all the operands are True then and then only op is True otherwise false.

# %%
var1 = True
var2 = False
var3 = True

print(var1 and var2 and var3)
# Out:
# False

# %%
jay = 22
viru = 20
gabbar = 23

if amt < bal and pin == 2435 :

# %% [markdown]
# ## or :->
#     If any operand is True then op is True.
#     If all the operands are False then and then only op is false.

# %%
c1 = "Samsung"
c2 = "Apple"
c3 = "Oppo"

if not(c1 == "oppo" or c1 =="Apple"):
    print("Koi bhi chalega")
print("End of program")
# Out:
# Koi bhi chalega
# End of program

# %% [markdown]
# ## not :-> Inversion operator

# %%
var = False


print(not var)
# Out:
# True
